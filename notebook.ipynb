# %%
# Using the GitHub API, to scrape users and their public repositories.

# %%
import os
import requests
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import json
from tqdm import tqdm

# %%
load_dotenv()
# Out:
# True

# %%
location = "Beijing"
min_followers = 500

# %% [markdown]
# # Fetch Users with Follower count condition

# %%
# This function reads Link header from response to navigate next page url

def get_next_page_url(response):
    link_header = response.headers.get('Link', '')
    # print(f"{link_header=}")
    next_page_url = None
    for x in link_header.split(","):
        match = re.search(r'<(.*)>; rel="next"', x)
        # print(match)
        if match:
            next_page_url = match.group(1)

    return next_page_url

# %%
# Fetch all users from location with min_followers count
url = f"https://api.github.com/search/users?q=location:{location}+followers:>{min_followers}&per_page=100"
headers = {"Accept": "application/vnd.github+json", "Authorization": f"Bearer {os.getenv("GITHUB_TOKEN")}"}

users = []
while True:
    print(url)
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Error fetching users: {response.text}")
        break
    
    data = response.json()
    users.extend(data["items"])
    next_page_url = get_next_page_url(response)
    print("Next:", next_page_url)
    if next_page_url is None:
        break

    url = next_page_url

len(users)
# Out:
# https://api.github.com/search/users?q=location:Beijing+followers:>500&per_page=100
# Next: https://api.github.com/search/users?q=location%3ABeijing+followers%3A%3E500&per_page=100&page=2
# https://api.github.com/search/users?q=location%3ABeijing+followers%3A%3E500&per_page=100&page=2
# Next: https://api.github.com/search/users?q=location%3ABeijing+followers%3A%3E500&per_page=100&page=3
# https://api.github.com/search/users?q=location%3ABeijing+followers%3A%3E500&per_page=100&page=3
# Next: https://api.github.com/search/users?q=location%3ABeijing+followers%3A%3E500&per_page=100&page=4
# https://api.github.com/search/users?q=location%3ABeijing+followers%3A%3E500&per_page=100&page=4
# Next: None
# 360

# %%
# Save users data to json file
with open("users.json", "w") as f:
    json.dump(users, f)

# %%
df_users = pd.DataFrame(users)

# %%
df_users.head()
# Out:
#              login        id               node_id  \
# 0      michaelliao    470058  MDQ6VXNlcjQ3MDA1OA==
# 1         daimajia   2503423  MDQ6VXNlcjI1MDM0MjM=
# 2          xiaolai    152970  MDQ6VXNlcjE1Mjk3MA==
# 3        draveness   6493255  MDQ6VXNlcjY0OTMyNTU=
# 4  hongyangAndroid  10704521  MDQ6VXNlcjEwNzA0NTIx
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/470058...
# 1  https://avatars.githubusercontent.com/u/250342...
# 2  https://avatars.githubusercontent.com/u/152970...
# 3  https://avatars.githubusercontent.com/u/649325...
# 4  https://avatars.githubusercontent.com/u/107045...
#
#                                             url  \
# 0      https://api.github.com/users/michaelliao
# 1         https://api.github.com/users/daimajia
# 2          https://api.github.com/users/xiaolai
# 3        https://api.github.com/users/draveness
# 4  https://api.github.com/users/hongyangAndroid
#
#                              html_url  \
# 0      https://github.com/michaelliao
# 1         https://github.com/daimajia
# 2          https://github.com/xiaolai
# 3        https://github.com/draveness
# 4  https://github.com/hongyangAndroid
#
#                                        followers_url  \
# 0  https://api.github.com/users/michaelliao/follo...
# 1    https://api.github.com/users/daimajia/followers
# 2     https://api.github.com/users/xiaolai/followers
# 3   https://api.github.com/users/draveness/followers
# 4  https://api.github.com/users/hongyangAndroid/f...
#
#                                        following_url  \
# 0  https://api.github.com/users/michaelliao/follo...
# 1  https://api.github.com/users/daimajia/followin...
# 2  https://api.github.com/users/xiaolai/following...
# 3  https://api.github.com/users/draveness/followi...
# 4  https://api.github.com/users/hongyangAndroid/f...
#
#                                            gists_url  \
# 0  https://api.github.com/users/michaelliao/gists...
# 1  https://api.github.com/users/daimajia/gists{/g...
# 2  https://api.github.com/users/xiaolai/gists{/gi...
# 3  https://api.github.com/users/draveness/gists{/...
# 4  https://api.github.com/users/hongyangAndroid/g...
#
#                                          starred_url  \
# 0  https://api.github.com/users/michaelliao/starr...
# 1  https://api.github.com/users/daimajia/starred{...
# 2  https://api.github.com/users/xiaolai/starred{/...
# 3  https://api.github.com/users/draveness/starred...
# 4  https://api.github.com/users/hongyangAndroid/s...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/michaelliao/subsc...
# 1  https://api.github.com/users/daimajia/subscrip...
# 2  https://api.github.com/users/xiaolai/subscript...
# 3  https://api.github.com/users/draveness/subscri...
# 4  https://api.github.com/users/hongyangAndroid/s...
#
#                                    organizations_url  \
# 0      https://api.github.com/users/michaelliao/orgs
# 1         https://api.github.com/users/daimajia/orgs
# 2          https://api.github.com/users/xiaolai/orgs
# 3        https://api.github.com/users/draveness/orgs
# 4  https://api.github.com/users/hongyangAndroid/orgs
#
#                                            repos_url  \
# 0     https://api.github.com/users/michaelliao/repos
# 1        https://api.github.com/users/daimajia/repos
# 2         https://api.github.com/users/xiaolai/repos
# 3       https://api.github.com/users/draveness/repos
# 4  https://api.github.com/users/hongyangAndroid/r...
#
#                                           events_url  \
# 0  https://api.github.com/users/michaelliao/event...
# 1  https://api.github.com/users/daimajia/events{/...
# 2  https://api.github.com/users/xiaolai/events{/p...
# 3  https://api.github.com/users/draveness/events{...
# 4  https://api.github.com/users/hongyangAndroid/e...
#
#                                  received_events_url  type user_view_type  \
# 0  https://api.github.com/users/michaelliao/recei...  User         public
# 1  https://api.github.com/users/daimajia/received...  User         public
# 2  https://api.github.com/users/xiaolai/received_...  User         public
# 3  https://api.github.com/users/draveness/receive...  User         public
# 4  https://api.github.com/users/hongyangAndroid/r...  User         public
#
#    site_admin  score
# 0       False    1.0
# 1       False    1.0
# 2       False    1.0
# 3       False    1.0
# 4       False    1.0

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   login                360 non-null    object
#  1   id                   360 non-null    int64
#  2   node_id              360 non-null    object
#  3   avatar_url           360 non-null    object
#  4   gravatar_id          360 non-null    object
#  5   url                  360 non-null    object
#  6   html_url             360 non-null    object
#  7   followers_url        360 non-null    object
#  8   following_url        360 non-null    object
#  9   gists_url            360 non-null    object
#  10  starred_url          360 non-null    object
#  11  subscriptions_url    360 non-null    object
#  12  organizations_url    360 non-null    object
#  13  repos_url            360 non-null    object
#  14  events_url           360 non-null    object
#  15  received_events_url  360 non-null    object
#  16  type                 360 non-null    object
#  17  user_view_type       360 non-null    object
#  18  site_admin           360 non-null    bool
#  19  score                360 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(17)
# memory usage: 53.9+ KB

# %%
df_users.isna().sum()
# Out:
# login                  0
# id                     0
# node_id                0
# avatar_url             0
# gravatar_id            0
# url                    0
# html_url               0
# followers_url          0
# following_url          0
# gists_url              0
# starred_url            0
# subscriptions_url      0
# organizations_url      0
# repos_url              0
# events_url             0
# received_events_url    0
# type                   0
# user_view_type         0
# site_admin             0
# score                  0
# dtype: int64

# %% [markdown]
# ## Fetch Repositories

# %%
# Fetch all public repositories of all above users
headers = {"Accept": "application/vnd.github+json", "Authorization": f"Bearer {os.getenv("GITHUB_TOKEN")}"}

repositories = []

for i, row in df_users.iterrows():
    username = row['login']

    url = f"https://api.github.com/users/{username}/repos"
    while True:
        print(url)
        response = requests.get(url, headers=headers)
        if response.status_code != 200:
            print(f"Error fetching users: {response.text}")
            break
        
        data = response.json()
        repositories.extend(data)
        next_page_url = get_next_page_url(response)
        print("Next:", next_page_url)
        if next_page_url is None:
            break
        url = next_page_url
    
len(repositories)
# Out:
# https://api.github.com/users/michaelliao/repos
# Next: https://api.github.com/user/470058/repos?page=2
# https://api.github.com/user/470058/repos?page=2
# Next: https://api.github.com/user/470058/repos?page=3
# https://api.github.com/user/470058/repos?page=3
# Next: https://api.github.com/user/470058/repos?page=4
# https://api.github.com/user/470058/repos?page=4
# Next: None
# https://api.github.com/users/daimajia/repos
# Next: https://api.github.com/user/2503423/repos?page=2
# https://api.github.com/user/2503423/repos?page=2
# Next: https://api.github.com/user/2503423/repos?page=3
# https://api.github.com/user/2503423/repos?page=3
# Next: None
# https://api.github.com/users/xiaolai/repos
# Next: https://api.github.com/user/152970/repos?page=2
# https://api.github.com/user/152970/repos?page=2
# Next: None
# https://api.github.com/users/draveness/repos
# Next: https://api.github.com/user/6493255/repos?page=2
# https://api.github.com/user/6493255/repos?page=2
# Next: None
# https://api.github.com/users/hongyangAndroid/repos
# Next: https://api.github.com/user/10704521/repos?page=2
# https://api.github.com/user/10704521/repos?page=2
# Next: https://api.github.com/user/10704521/repos?page=3
# https://api.github.com/user/10704521/repos?page=3
# Next: https://api.github.com/user/10704521/repos?page=4
# https://api.github.com/user/10704521/repos?page=4
# Next: None
# https://api.github.com/users/haoel/repos
# Next: None
# https://api.github.com/users/wizardforcel/repos
# Next: https://api.github.com/user/5080126/repos?page=2
# https://api.github.com/user/5080126/repos?page=2
# Next: https://api.github.com/user/5080126/repos?page=3
# https://api.github.com/user/5080126/repos?page=3
# Next: None
# https://api.github.com/users/i5ting/repos
# Next: https://api.github.com/user/3118295/repos?page=2
# https://api.github.com/user/3118295/repos?page=2
# Next: https://api.github.com/user/3118295/repos?page=3
# https://api.github.com/user/3118295/repos?page=3
# Next: https://api.github.com/user/3118295/repos?page=4
# https://api.github.com/user/3118295/repos?page=4
# Next: https://api.github.com/user/3118295/repos?page=5
# https://api.github.com/user/3118295/repos?page=5
# Next: https://api.github.com/user/3118295/repos?page=6
# https://api.github.com/user/3118295/repos?page=6
# Next: https://api.github.com/user/3118295/repos?page=7
# https://api.github.com/user/3118295/repos?page=7
# Next: https://api.github.com/user/3118295/repos?page=8
# https://api.github.com/user/3118295/repos?page=8
# Next: https://api.github.com/user/3118295/repos?page=9
# https://api.github.com/user/3118295/repos?page=9
# Next: https://api.github.com/user/3118295/repos?page=10
# https://api.github.com/user/3118295/repos?page=10
# Next: https://api.github.com/user/3118295/repos?page=11
# https://api.github.com/user/3118295/repos?page=11
# Next: https://api.github.com/user/3118295/repos?page=12
# https://api.github.com/user/3118295/repos?page=12
# Next: https://api.github.com/user/18389035/repos?page=2
# https://api.github.com/user/18389035/repos?page=2
# Next: https://api.github.com/user/18389035/repos?page=3
# https://api.github.com/user/18389035/repos?page=3
# Next: https://api.github.com/user/18389035/repos?page=4
# https://api.github.com/user/18389035/repos?page=4
# Next: https://api.github.com/user/18389035/repos?page=5
# https://api.github.com/user/18389035/repos?page=5
# Next: https://api.github.com/user/18389035/repos?page=6
# https://api.github.com/user/18389035/repos?page=6
# Next: https://api.github.com/user/18389035/repos?page=7
# https://api.github.com/user/18389035/repos?page=7
# Next: https://api.github.com/user/18389035/repos?page=8
# https://api.github.com/user/18389035/repos?page=8
# Next: None
# https://api.github.com/users/zhengmin1989/repos
# Next: None
# https://api.github.com/users/baoyongzhang/repos
# Next: https://api.github.com/user/4636761/repos?page=2
# https://api.github.com/user/4636761/repos?page=2
# Next: None
# https://api.github.com/users/wendux/repos
# Next: https://api.github.com/user/20411648/repos?page=2
# https://api.github.com/user/20411648/repos?page=2
# Next: None
# https://api.github.com/users/shenghy/repos
# Next: None
# https://api.github.com/users/polaris1119/repos
# Next: https://api.github.com/user/899673/repos?page=2
# https://api.github.com/user/899673/repos?page=2
# Next: https://api.github.com/user/899673/repos?page=3
# https://api.github.com/user/899673/repos?page=3
# Next: https://api.github.com/user/899673/repos?page=4
# https://api.github.com/user/899673/repos?page=4
# Next: https://api.github.com/user/899673/repos?page=5
# https://api.github.com/user/899673/repos?page=5
# Next: None
# https://api.github.com/users/dexteryy/repos
# Next: https://api.github.com/user/43011/repos?page=2
# https://api.github.com/user/43011/repos?page=2
# Next: https://api.github.com/user/43011/repos?page=3
# https://api.github.com/user/43011/repos?page=3
# Next: None
# https://api.github.com/users/lotem/repos
# Next: https://api.github.com/user/151157/repos?page=2
# https://api.github.com/user/151157/repos?page=2
# Next: https://api.github.com/user/151157/repos?page=3
# https://api.github.com/user/151157/repos?page=3
# Next: https://api.github.com/user/151157/repos?page=4
# https://api.github.com/user/151157/repos?page=4
# Next: None
# https://api.github.com/users/yangfuhai/repos
# Next: https://api.github.com/user/1539806/repos?page=2
# https://api.github.com/user/1539806/repos?page=2
# Next: https://api.github.com/user/1539806/repos?page=3
# https://api.github.com/user/1539806/repos?page=3
# Next: None
# https://api.github.com/users/hiyouga/repos
# Next: https://api.github.com/user/16256802/repos?page=2
# https://api.github.com/user/16256802/repos?page=2
# Next: None
# https://api.github.com/users/bennyhuo/repos
# Next: https://api.github.com/user/6336960/repos?page=2
# https://api.github.com/user/6336960/repos?page=2
# Next: https://api.github.com/user/6336960/repos?page=3
# https://api.github.com/user/6336960/repos?page=3
# Next: https://api.github.com/user/6336960/repos?page=4
# https://api.github.com/user/6336960/repos?page=4
# Next: None
# https://api.github.com/users/soulteary/repos
# Next: https://api.github.com/user/1500781/repos?page=2
# https://api.github.com/user/1500781/repos?page=2
# Next: https://api.github.com/user/1500781/repos?page=3
# https://api.github.com/user/1500781/repos?page=3
# Next: https://api.github.com/user/1500781/repos?page=4
# https://api.github.com/user/1500781/repos?page=4
# Next: https://api.github.com/user/1500781/repos?page=5
# https://api.github.com/user/1500781/repos?page=5
# Next: https://api.github.com/user/1500781/repos?page=6
# https://api.github.com/user/1500781/repos?page=6
# Next: https://api.github.com/user/1500781/repos?page=7
# https://api.github.com/user/1500781/repos?page=7
# Next: https://api.github.com/user/1500781/repos?page=8
# https://api.github.com/user/1500781/repos?page=8
# Next: https://api.github.com/user/1500781/repos?page=9
# https://api.github.com/user/1500781/repos?page=9
# Next: https://api.github.com/user/1500781/repos?page=10
# https://api.github.com/user/1500781/repos?page=10
# Next: https://api.github.com/user/1500781/repos?page=11
# https://api.github.com/user/1500781/repos?page=11
# Next: None
# https://api.github.com/users/taowen/repos
# Next: https://api.github.com/user/40541/repos?page=2
# https://api.github.com/user/40541/repos?page=2
# Next: https://api.github.com/user/40541/repos?page=3
# https://api.github.com/user/40541/repos?page=3
# Next: None
# https://api.github.com/users/Yixiaohan/repos
# Next: None
# https://api.github.com/users/ouyangzhiping/repos
# Next: None
# https://api.github.com/users/foolwood/repos
# Next: None
# https://api.github.com/users/baidu/repos
# Next: https://api.github.com/user/13245940/repos?page=2
# https://api.github.com/user/13245940/repos?page=2
# Next: https://api.github.com/user/13245940/repos?page=3
# https://api.github.com/user/13245940/repos?page=3
# Next: https://api.github.com/user/13245940/repos?page=4
# https://api.github.com/user/13245940/repos?page=4
# Next: None
# https://api.github.com/users/ideawu/repos
# Next: https://api.github.com/user/3202758/repos?page=2
# https://api.github.com/user/3202758/repos?page=2
# Next: None
# https://api.github.com/users/chaoslawful/repos
# Next: https://api.github.com/user/56617/repos?page=2
# https://api.github.com/user/56617/repos?page=2
# Next: None
# https://api.github.com/users/bestswifter/repos
# Next: https://api.github.com/user/8394612/repos?page=2
# https://api.github.com/user/8394612/repos?page=2
# Next: None
# https://api.github.com/users/shibing624/repos
# Next: https://api.github.com/user/10249622/repos?page=2
# https://api.github.com/user/10249622/repos?page=2
# Next: https://api.github.com/user/10249622/repos?page=3
# https://api.github.com/user/10249622/repos?page=3
# Next: None
# https://api.github.com/users/hyper0x/repos
# Next: https://api.github.com/user/315569/repos?page=2
# https://api.github.com/user/315569/repos?page=2
# Next: None
# https://api.github.com/users/L1aoXingyu/repos
# Next: https://api.github.com/user/19245504/repos?page=2
# https://api.github.com/user/19245504/repos?page=2
# Next: https://api.github.com/user/19245504/repos?page=3
# https://api.github.com/user/19245504/repos?page=3
# Next: https://api.github.com/user/19245504/repos?page=4
# https://api.github.com/user/19245504/repos?page=4
# Next: https://api.github.com/user/19245504/repos?page=5
# https://api.github.com/user/19245504/repos?page=5
# Next: https://api.github.com/user/19245504/repos?page=6
# https://api.github.com/user/19245504/repos?page=6
# Next: None
# https://api.github.com/users/terrymanu/repos
# Next: None
# https://api.github.com/users/icarusion/repos
# Next: https://api.github.com/user/5370542/repos?page=2
# https://api.github.com/user/5370542/repos?page=2
# Next: https://api.github.com/user/5370542/repos?page=3
# https://api.github.com/user/5370542/repos?page=3
# Next: None
# https://api.github.com/users/MartinRGB/repos
# Next: https://api.github.com/user/7036706/repos?page=2
# Next: https://api.github.com/user/23165266/repos?page=2
# https://api.github.com/user/23165266/repos?page=2
# Next: None
# https://api.github.com/users/chaitin/repos
# Next: https://api.github.com/user/7302766/repos?page=2
# https://api.github.com/user/7302766/repos?page=2
# Next: None
# https://api.github.com/users/reeze/repos
# Next: https://api.github.com/user/14658/repos?page=2
# https://api.github.com/user/14658/repos?page=2
# Next: https://api.github.com/user/14658/repos?page=3
# https://api.github.com/user/14658/repos?page=3
# Next: https://api.github.com/user/14658/repos?page=4
# https://api.github.com/user/14658/repos?page=4
# Next: https://api.github.com/user/14658/repos?page=5
# https://api.github.com/user/14658/repos?page=5
# Next: https://api.github.com/user/14658/repos?page=6
# https://api.github.com/user/14658/repos?page=6
# Next: None
# https://api.github.com/users/Sophia-11/repos
# Next: None
# https://api.github.com/users/DianQK/repos
# Next: https://api.github.com/user/10829914/repos?page=2
# https://api.github.com/user/10829914/repos?page=2
# Next: https://api.github.com/user/10829914/repos?page=3
# https://api.github.com/user/10829914/repos?page=3
# Next: None
# https://api.github.com/users/neil3d/repos
# Next: None
# https://api.github.com/users/pezy/repos
# Next: https://api.github.com/user/1147451/repos?page=2
# https://api.github.com/user/1147451/repos?page=2
# Next: https://api.github.com/user/1147451/repos?page=3
# https://api.github.com/user/1147451/repos?page=3
# Next: None
# https://api.github.com/users/huxiaoman7/repos
# Next: https://api.github.com/user/19527386/repos?page=2
# https://api.github.com/user/19527386/repos?page=2
# Next: None
# https://api.github.com/users/anjoy8/repos
# Next: https://api.github.com/user/28941816/repos?page=2
# https://api.github.com/user/28941816/repos?page=2
# Next: None
# https://api.github.com/users/aa65535/repos
# Next: None
# https://api.github.com/users/welefen/repos
# Next: https://api.github.com/user/40935/repos?page=2
# https://api.github.com/user/40935/repos?page=2
# Next: None
# https://api.github.com/users/MiCode/repos
# Next: https://api.github.com/user/1274540/repos?page=2
# https://api.github.com/user/1274540/repos?page=2
# Next: https://api.github.com/user/1274540/repos?page=3
# https://api.github.com/user/1274540/repos?page=3
# Next: None
# https://api.github.com/users/vincent4j/repos
# Next: None
# https://api.github.com/users/Naituw/repos
# Next: https://api.github.com/user/353943/repos?page=2
# https://api.github.com/user/353943/repos?page=2
# Next: https://api.github.com/user/353943/repos?page=3
# https://api.github.com/user/353943/repos?page=3
# Next: None
# https://api.github.com/users/zxlie/repos
# Next: https://api.github.com/user/865735/repos?page=2
# https://api.github.com/user/865735/repos?page=2
# Next: None
# https://api.github.com/users/tuna/repos
# Next: https://api.github.com/user/9341563/repos?page=2
# https://api.github.com/user/9341563/repos?page=2
# Next: None
# https://api.github.com/users/msnh2012/repos
# Next: https://api.github.com/user/17841334/repos?page=2
# https://api.github.com/user/17841334/repos?page=2
# Next: https://api.github.com/user/17841334/repos?page=3
# https://api.github.com/user/17841334/repos?page=3
# Next: https://api.github.com/user/17841334/repos?page=4
# https://api.github.com/user/17841334/repos?page=4
# Next: https://api.github.com/user/17841334/repos?page=5
# https://api.github.com/user/17841334/repos?page=5
# Next: https://api.github.com/user/17841334/repos?page=6
# Next: https://api.github.com/user/11471150/repos?page=16
# https://api.github.com/user/11471150/repos?page=16
# Next: None
# https://api.github.com/users/Apache9/repos
# Next: https://api.github.com/user/4958168/repos?page=2
# https://api.github.com/user/4958168/repos?page=2
# Next: None
# https://api.github.com/users/jimmysoa/repos
# Next: None
# https://api.github.com/users/sumory/repos
# Next: https://api.github.com/user/1326893/repos?page=2
# https://api.github.com/user/1326893/repos?page=2
# Next: None
# https://api.github.com/users/q191201771/repos
# Next: https://api.github.com/user/6093955/repos?page=2
# https://api.github.com/user/6093955/repos?page=2
# Next: None
# https://api.github.com/users/nice0e3/repos
# Next: None
# https://api.github.com/users/SmartDengg/repos
# Next: https://api.github.com/user/15685298/repos?page=2
# https://api.github.com/user/15685298/repos?page=2
# Next: None
# https://api.github.com/users/wanglong/repos
# Next: https://api.github.com/user/316074/repos?page=2
# https://api.github.com/user/316074/repos?page=2
# Next: https://api.github.com/user/316074/repos?page=3
# https://api.github.com/user/316074/repos?page=3
# Next: https://api.github.com/user/316074/repos?page=4
# https://api.github.com/user/316074/repos?page=4
# Next: https://api.github.com/user/316074/repos?page=5
# https://api.github.com/user/316074/repos?page=5
# Next: https://api.github.com/user/316074/repos?page=6
# https://api.github.com/user/316074/repos?page=6
# Next: https://api.github.com/user/316074/repos?page=7
# https://api.github.com/user/316074/repos?page=7
# Next: https://api.github.com/user/316074/repos?page=8
# https://api.github.com/user/316074/repos?page=8
# Next: https://api.github.com/user/316074/repos?page=9
# https://api.github.com/user/316074/repos?page=9
# Next: https://api.github.com/user/316074/repos?page=10
# https://api.github.com/user/316074/repos?page=10
# Next: https://api.github.com/user/316074/repos?page=11
# https://api.github.com/user/316074/repos?page=11
# Next: https://api.github.com/user/316074/repos?page=12
# https://api.github.com/user/316074/repos?page=12
# Next: https://api.github.com/user/316074/repos?page=13
# https://api.github.com/user/316074/repos?page=13
# Next: https://api.github.com/user/316074/repos?page=14
# https://api.github.com/user/316074/repos?page=14
# Next: https://api.github.com/user/316074/repos?page=15
# https://api.github.com/user/316074/repos?page=15
# Next: https://api.github.com/user/316074/repos?page=16
# https://api.github.com/user/316074/repos?page=16
# Next: https://api.github.com/user/316074/repos?page=17
# https://api.github.com/user/316074/repos?page=17
# Next: https://api.github.com/user/316074/repos?page=18
# https://api.github.com/user/316074/repos?page=18
# Next: https://api.github.com/user/316074/repos?page=19
# https://api.github.com/user/316074/repos?page=19
# Next: https://api.github.com/user/316074/repos?page=20
# https://api.github.com/user/316074/repos?page=20
# Next: https://api.github.com/user/316074/repos?page=21
# https://api.github.com/user/316074/repos?page=21
# Next: None
# https://api.github.com/users/CreditTone/repos
# Next: https://api.github.com/user/7986355/repos?page=2
# https://api.github.com/user/7986355/repos?page=2
# Next: None
# https://api.github.com/users/guoyaohua/repos
# Next: https://api.github.com/user/20484437/repos?page=2
# https://api.github.com/user/20484437/repos?page=2
# Next: None
# https://api.github.com/users/leerumor/repos
# Next: None
# https://api.github.com/users/wuyawei/repos
# Next: None
# https://api.github.com/users/icexin/repos
# https://api.github.com/user/4639578/repos?page=10
# Next: None
# https://api.github.com/users/qcrao/repos
# Next: https://api.github.com/user/7698088/repos?page=2
# https://api.github.com/user/7698088/repos?page=2
# Next: https://api.github.com/user/7698088/repos?page=3
# https://api.github.com/user/7698088/repos?page=3
# Next: https://api.github.com/user/7698088/repos?page=4
# https://api.github.com/user/7698088/repos?page=4
# Next: https://api.github.com/user/7698088/repos?page=5
# https://api.github.com/user/7698088/repos?page=5
# Next: None
# https://api.github.com/users/VincentWei/repos
# Next: https://api.github.com/user/1990953/repos?page=2
# https://api.github.com/user/1990953/repos?page=2
# Next: None
# https://api.github.com/users/Relph1119/repos
# Next: https://api.github.com/user/15226799/repos?page=2
# https://api.github.com/user/15226799/repos?page=2
# Next: https://api.github.com/user/15226799/repos?page=3
# https://api.github.com/user/15226799/repos?page=3
# Next: https://api.github.com/user/15226799/repos?page=4
# https://api.github.com/user/15226799/repos?page=4
# Next: None
# https://api.github.com/users/yxgeee/repos
# Next: None
# https://api.github.com/users/leiurayer/repos
# Next: None
# https://api.github.com/users/sjsdfg/repos
# Next: https://api.github.com/user/8037152/repos?page=2
# https://api.github.com/user/8037152/repos?page=2
# Next: None
# https://api.github.com/users/yu-changqian/repos
# Next: None
# https://api.github.com/users/xtlsoft/repos
# Next: https://api.github.com/user/16159830/repos?page=2
# https://api.github.com/user/16159830/repos?page=2
# Next: https://api.github.com/user/16159830/repos?page=3
# https://api.github.com/user/16159830/repos?page=3
# Next: https://api.github.com/user/16159830/repos?page=4
# https://api.github.com/user/16159830/repos?page=4
# Next: None
# https://api.github.com/users/JasinYip/repos
# Next: https://api.github.com/user/7105264/repos?page=2
# https://api.github.com/user/7105264/repos?page=2
# Next: None
# https://api.github.com/users/insightglacier/repos
# Next: https://api.github.com/user/2887799/repos?page=2
# https://api.github.com/user/2887799/repos?page=2
# Next: https://api.github.com/user/2887799/repos?page=3
# https://api.github.com/user/2887799/repos?page=3
# Next: https://api.github.com/user/2887799/repos?page=4
# https://api.github.com/user/2887799/repos?page=4
# Next: None
# https://api.github.com/users/zythum/repos
# Next: None
# https://api.github.com/users/zhangzichao/repos
# Next: None
# https://api.github.com/users/fuxuemingzhu/repos
# Next: https://api.github.com/user/8588251/repos?page=2
# https://api.github.com/user/8588251/repos?page=2
# Next: None
# https://api.github.com/users/tcc0lin/repos
# Next: https://api.github.com/user/46896960/repos?page=2
# https://api.github.com/user/46896960/repos?page=2
# Next: None
# https://api.github.com/users/runner365/repos
# Next: None
# 32358

# %%
len(repositories)
# Out:
# 32358

# %%
# save repositories data to json file
with open("repositories.json", "w") as f:
    json.dump(repositories, f)

# %%
len(users),len(repositories)
# Out:
# (360, 32358)

# %% [markdown]
# # Fetch user profiles

# %%
# Fetch user profiles 
headers = {"Accept": "application/vnd.github+json", "Authorization": f"Bearer {os.getenv("GITHUB_TOKEN")}"}
user_profiles = []
for i, row in tqdm(df_users.iterrows()):
    username = row['login']
    url = f"https://api.github.com/users/{username}"
    # print(url)
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Error fetching users: {response.text}")
        break
    
    user_profiles.append(response.json())
    
len(user_profiles)
# Out:
# 360it [02:31,  2.38it/s]
# 360

# %%
# Save user profiles to JSON file
with open("user_profiles.json", "w") as f:
    json.dump(user_profiles, f)

# %% [markdown]
# # Load data back again from JSON files

# %%
with open("users.json") as f:
    users = json.load(f)

# %%
with open("repositories.json") as f:
    repositories = json.load(f)

# %%
with open("user_profiles.json") as f:
    user_profiles = json.load(f)

# %%
df_users = pd.DataFrame(users)
df_user_profiles = pd.DataFrame(user_profiles)
df_repositories = pd.DataFrame(repositories)

# %% [markdown]
# ## Users data cleaning
#
#  * login: Their Github user ID
#  * name: Their full name
#  * company: The company they work at. Clean up company names. At least make sure:
#    * They're trimmed of whitespace
#    * Leading @ symbols are stripped
#    * They are converted to UPPERCASE
#
#  * location: The city they are in
#  * email: Their email address
#  * hireable: Whether they are open to being hired
#  * bio: A short bio about them
#  * public_repos: The number of public repositories they have
#  * followers: The number of followers they have
#  * following: The number of people they are following
#  * created_at: When they joined Github

# %% [markdown]
# ```
# user.login
# profile.name
# profile.company -> re.sub(r'(^@)|(\s@)', ' ', companies).strip().upper()
# profile.location
# profile.email
# profile.hireable -> map {True: 'true', False: 'false', None: ''}
# profile.bio
# profile.public_repos
# profile.followers
# profile.following
# profile.created_at
# ```

# %%
df_profiles = pd.DataFrame(user_profiles)

# %%
df_user_profiles = df_profiles[["login", "name", "company", "location", "email", "hireable", "bio", "public_repos", "followers", "following", "created_at"]].fillna('')
df_user_profiles["company"] = df_user_profiles["company"].map(lambda x: re.sub(r'(^@)|(\s@)', ' ', x).strip().upper())
# df_user_profiles.loc[df_user_profiles["hireable"] == True, "hireable"] = 'true'
# df_user_profiles.loc[df_user_profiles["hireable"] == False, "hireable"] = 'false'
# df_user_profiles.info()

df_user_profiles.head()
# Out:
#              login            name           company        location  \
# 0      michaelliao  Crypto Michael                    Beijing, China
# 1         daimajia             代码家  ZHENFUND BEIJING  Beijing, China
# 2          xiaolai         xiaolai      INBLOCKCHAIN         beijing
# 3        draveness          Draven      SPECTRA-FUND  Beijing, China
# 4  hongyangAndroid             张鸿洋    WANANDROID.COM   Beijing,China
#
#                   email hireable                         bio  public_repos  \
# 0  askxuefeng@gmail.com                    Crypto developer.            99
# 1    daimajia@gmail.com           Zhenfund VP of Investment.            89
# 2   lixiaolai@gmail.com                  A lifelong student.            55
# 3           i@draven.co     True              HFT / C++ / Go            50
# 4      623565791@qq.com     True                       学习ing           102
#
#    followers  following            created_at
# 0      37254          3  2010-11-06T12:21:35Z
# 1      24631        271  2012-10-07T02:40:06Z
# 2      19268         37  2009-11-13T18:29:42Z
# 3      13010         28  2014-01-24T16:22:01Z
# 4      12986         35  2015-01-26T07:05:45Z

# %%
df_user_profiles.to_csv("users.csv", index=False)

# %% [markdown]
# ## Repositories data cleaning
#
# For each user in users.csv, fetch up to the 500 most recently pushed repositories, with fields:
#
# ```
# login: The Github user ID (login) of the owner, which, BTW, is not directly in the API response.)
#
# full_name: Full name of the repository
#
# created_at: When the repository was created
#
# stargazers_count: Number of stars the repository has
#
# watchers_count: Number of watchers the repository has
#
# language: The programming language the repository is written in
#
# has_projects: Whether the repository has projects enabled
#   -> map {True: 'true', False: 'false', None: ''}
#
# has_wiki: Whether the repository has a wiki
#   -> map {True: 'true', False: 'false', None: ''}
#
# license_name: Name of the license the repository is under (This is under license.key)
# ```

# %%
df_repositories = pd.DataFrame(repositories)

# %%
df_all_repos = df_repositories.copy()
df_all_repos["license_name"] = df_all_repos["license"].map(lambda x: x["key"] if x else None)
df_all_repos["login"] = df_all_repos["owner"].map(lambda x: x["login"])
df_all_repos = df_all_repos[["login", "full_name", "created_at", "pushed_at",
                             "stargazers_count", "watchers_count", "language", "has_projects", "has_wiki", "license_name"]]

#df_all_repos.loc[df_all_repos["has_projects"] == True, "has_projects"] = 'true'
#df_all_repos.loc[df_all_repos["has_projects"] == False, "has_projects"] = 'false'
#df_all_repos.loc[df_all_repos["has_wiki"] == True, "has_wiki"] = 'true'
#df_all_repos.loc[df_all_repos["has_wiki"] == False, "has_wiki"] = 'false'

# df_all_repos = df_all_repos.fillna('')
df_all_repos.info()
# df_all_repos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32358 entries, 0 to 32357
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   login             32358 non-null  object
#  1   full_name         32358 non-null  object
#  2   created_at        32358 non-null  object
#  3   pushed_at         32349 non-null  object
#  4   stargazers_count  32358 non-null  int64
#  5   watchers_count    32358 non-null  int64
#  6   language          22367 non-null  object
#  7   has_projects      32358 non-null  bool
#  8   has_wiki          32358 non-null  bool
#  9   license_name      17616 non-null  object
# dtypes: bool(2), int64(2), object(6)
# memory usage: 2.0+ MB

# %%
for g, df in df_all_repos.groupby("login"):
    prevlen, nextlen = len(df), len(df.sort_values("pushed_at", ascending=False).head(500))
    if(prevlen != nextlen):
        print(g, prevlen, nextlen)
# Out:
# LinuxSuRen 1842 500
# hailiang-wang 1058 500
# i5ting 902 500
# wanglong 610 500
# xiaoweiruby 860 500

# %%
df_all_repos = (
    df_all_repos.groupby("login")
    .apply(lambda df: df.sort_values("pushed_at").head(500),
           include_groups=True
          )
    .reset_index(drop=True)
    .drop(columns=["pushed_at"])
)

df_all_repos.sample(10)
# Out:
# /tmp/ipykernel_16159/2237439731.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda df: df.sort_values("pushed_at").head(500),
#               login                          full_name            created_at  \
# 5225          Vonng                         Vonng/blog  2017-12-13T05:20:10Z
# 6270   ZhaoKaiQiang  ZhaoKaiQiang/PagerSlidingTabStrip  2014-10-21T09:46:00Z
# 2305       JasinYip                     JasinYip/babel  2022-02-16T11:14:11Z
# 26977   xiaoweiruby       xiaoweiruby/vue-music-player  2018-04-04T01:55:35Z
# 29445        zswang                  zswang/h5i18n-php  2017-07-04T13:44:34Z
# 16215        liubin              liubin/ConsoleMonitor  2013-11-09T03:37:25Z
# 6409        Zheaoli                  Zheaoli/recursion  2017-12-06T10:24:29Z
# 27182    xiaye13579                  xiaye13579/xUtils  2015-04-28T02:09:18Z
# 8975        cundong                     cundong/blog-1  2015-05-07T09:07:39Z
# 21245    rfyiamcool              rfyiamcool/python-pid  2015-09-16T16:07:02Z
#
#        stargazers_count  watchers_count          language  has_projects  \
# 5225                  7               7  Jupyter Notebook          True
# 6270                  0               0              None          True
# 2305                  0               0        TypeScript          True
# 26977                 0               0               Vue          True
# 29445                 0               0               PHP          True
# 16215                 0               0              Java          True
# 6409                  0               0  Jupyter Notebook          True
# 27182                 0               0              Java          True
# 8975                  0               0              None          True
# 21245                 5               5            Python          True
#
#        has_wiki license_name
# 5225       True         None
# 6270       True         None
# 2305      False          mit
# 26977      True         None
# 29445      True         None
# 16215      True         None
# 6409       True         None
# 27182      True         None
# 8975       True   apache-2.0
# 21245      True          mit

# %%
# Write to csv
df_all_repos.to_csv("repositories.csv", index=False)

# %%
df_all_repos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29586 entries, 0 to 29585
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   login             29586 non-null  object
#  1   full_name         29586 non-null  object
#  2   created_at        29586 non-null  object
#  3   stargazers_count  29586 non-null  int64
#  4   watchers_count    29586 non-null  int64
#  5   language          21105 non-null  object
#  6   has_projects      29586 non-null  bool
#  7   has_wiki          29586 non-null  bool
#  8   license_name      15854 non-null  object
# dtypes: bool(2), int64(2), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Analysis

# %%
# 1. Who are the top 5 users in Beijing with the highest number of followers? List their login in order, comma-separated.

df_filtered = df_user_profiles.sort_values("followers", ascending=False).head(5)
users_list = df_filtered["login"].values
",".join(users_list)
# df_filtered
# Out:
# 'michaelliao,daimajia,xiaolai,draveness,hongyangAndroid'

# %%
# 2. Who are the 5 earliest registered GitHub users in Beijing? List their login in ascending order of created_at, comma-separated.

df_filtered = df_user_profiles.sort_values("created_at", ascending=True).head(5)
users_list = df_filtered["login"].values
",".join(users_list)
# df_filtered
# Out:
# 'robin,nwind,reeze,kejun,ZhangHanDong'

# %%
# 3. What are the 3 most popular license among these users? Ignore missing licenses. List the license_name in order, comma-separated.


df_filtered = df_all_repos[df_all_repos.license_name != ''].license_name.value_counts().head(3).reset_index()
license_list = df_filtered.license_name.values
",".join(license_list)
# Out:
# 'mit,apache-2.0,other'

# %%
# 4. Which company do the majority of these developers work at?


df_user_profiles[df_user_profiles.company != ''].value_counts("company", ascending=False).head()
# Out:
# company
# BYTEDANCE              12
# ALIBABA                 9
# TSINGHUA UNIVERSITY     7
# PEKING UNIVERSITY       7
# TENCENT                 6
# Name: count, dtype: int64

# %%
# 5. Which programming language is most popular among these users?

df_all_repos.value_counts("language", ascending=False).head()
# Out:
# language
# JavaScript    4422
# Python        3259
# Java          2368
# Go            1365
# C++           1214
# Name: count, dtype: int64

# %%
# 6. Which programming language is the second most popular among users who joined after 2020?

selected_users = df_user_profiles[pd.to_datetime(df_user_profiles.created_at).dt.year >= 2020].login

df_all_repos[df_all_repos.login.isin(selected_users)].value_counts("language", ascending=False).head()
# Out:
# language
# Python              32
# JavaScript          24
# HTML                19
# TypeScript          16
# Jupyter Notebook    12
# Name: count, dtype: int64

# %%
# 7. Which language has the highest average number of stars per repository?

df_all_repos.groupby("language")["stargazers_count"].mean().reset_index().sort_values("stargazers_count", ascending=False).head(2)
# Out:
#      language  stargazers_count
# 52      Jinja       3431.000000
# 114  Solidity       1290.555556

# %%
# 8. Let's define leader_strength as followers / (1 + following). Who are the top 5 in terms of leader_strength?
# List their login in order, comma-separated.

df_leader = df_user_profiles.copy()
df_leader.head()
# leader_strength as followers / (1 + following).
df_leader["leader_strength"] = df_leader["followers"] / (1 + df_leader["following"])

# %%
df_filtered = df_leader.sort_values("leader_strength", ascending=False)[["login", "leader_strength"]].head()
login_list = df_filtered.login.values
",".join(login_list)
# Out:
# 'michaelliao,ityouknow,liuhuanyong,thunlp,shenghy'

# %%
# 9. What is the correlation between the number of followers and the number of public repositories among users in Beijing?
# Correlation between followers and repos (to 3 decimal places, e.g. 0.123 or -0.123)

df_user_profiles[["public_repos", "followers"]].corr()
# Out:
#               public_repos  followers
# public_repos      1.000000   0.032918
# followers         0.032918   1.000000

# %%
df_user_profiles.head(2)
# Out:
#          login            name           company        location  \
# 0  michaelliao  Crypto Michael                    Beijing, China
# 1     daimajia             代码家  ZHENFUND BEIJING  Beijing, China
#
#                   email hireable                         bio  public_repos  \
# 0  askxuefeng@gmail.com                    Crypto developer.            99
# 1    daimajia@gmail.com           Zhenfund VP of Investment.            89
#
#    followers  following            created_at
# 0      37254          3  2010-11-06T12:21:35Z
# 1      24631        271  2012-10-07T02:40:06Z

# %%
# 10. Does creating more repos help users get more followers? Using regression, 
# estimate how many additional followers a user gets per additional public repository.
# regression slope of followers on repos (to 3 decimal places, e.g. 0.123 or -0.123)

from sklearn.linear_model import LinearRegression

# %%
X = df_user_profiles[["public_repos"]]
y = df_user_profiles["followers"]
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
np.round(model.coef_, 3), model.intercept_
# Out:
# (array([0.657]), 1591.3537784716464)

# %%
# 11. Do people typically enable projects and wikis together? 
# What is the correlation between a repo having projects enabled and having wiki enabled?

df2 = df_all_repos[["has_projects", "has_wiki"]].copy()
#df2["has_projects"] = df2["has_projects"].map(lambda x: True if x == 'true' else False if x == 'false' else np.nan)
#df2["has_wiki"] = df2["has_projects"].map(lambda x: True if x == 'true' else False if x == 'false' else np.nan)
df2.dtypes
print(np.round(df2.corr().iloc[0,1] ,3))
df2.corr()
# df2.corr().iloc[0,1]
# Out:
# 0.272
#               has_projects  has_wiki
# has_projects      1.000000  0.272323
# has_wiki          0.272323  1.000000

# %%
df2.dtypes
# Out:
# has_projects    bool
# has_wiki        bool
# dtype: object

# %%
# 12. Do hireable users follow more people than those who are not hireable?
# Average of following per user for hireable=true minus the average following for the rest (to 3 decimal places, e.g. 12.345 or -12.345)

# %%
df_user_profiles.head(2)
# Out:
#          login            name           company        location  \
# 0  michaelliao  Crypto Michael                    Beijing, China
# 1     daimajia             代码家  ZHENFUND BEIJING  Beijing, China
#
#                   email hireable                         bio  public_repos  \
# 0  askxuefeng@gmail.com                    Crypto developer.            99
# 1    daimajia@gmail.com           Zhenfund VP of Investment.            89
#
#    followers  following            created_at
# 0      37254          3  2010-11-06T12:21:35Z
# 1      24631        271  2012-10-07T02:40:06Z

# %%
hireable_mean_followers = df_user_profiles[df_user_profiles.hireable == True].following.mean()
non_hireable_mean_followers = df_user_profiles[df_user_profiles.hireable != True].following.mean()
hireable_mean_followers, non_hireable_mean_followers, np.round(hireable_mean_followers - non_hireable_mean_followers, 3)
# Out:
# (267.7029702970297, 118.1891891891892, 149.514)

# %%
df3.head(3)
# Out:
#                           bio  followers  bio_word_count
# 0           Crypto developer.      37255               2
# 1  Zhenfund VP of Investment.      24631               4
# 2         A lifelong student.      19265               3

# %%
# 13. Some developers write long bios. Does that help them get more followers? 
# What's the correlation of the length of their bio (in Unicode words, split by whitespace) with followers?
# (Ignore people without bios)
# Regression slope of followers on bio word count (to 3 decimal places, e.g. 12.345 or -12.345)

# Filter user with empty bio
df3 = df_user_profiles[df_user_profiles.bio.str.strip().str.len() > 0][["bio", "followers"]].copy()
# Count words in bio
df3["bio_word_count"] = df3.bio.str.split().str.len()
X = df3[["bio_word_count"]]
y = df3["followers"]

model = LinearRegression()
model.fit(X, y)
np.round(model.intercept_, 3), np.round(model.coef_, 3)
#, np.round(df3[["bio_word_count", "followers"]].corr(), 3)
# Out:
# (1865.047, array([-12.112]))

# %%
# m,b = np.polyfit(df3["followers"], df3["bio_word_count"], 1)
m,b = np.polyfit(df3["bio_word_count"], df3["followers"], 1)
np.round(m, 3), b
# Out:
# (-12.112, 1865.0467414836678)

# %%
# Who created the most repositories on weekends (UTC)? List the top 5 users' login in order, comma-separated
# Users login


df4 = df_all_repos.copy()
df4["created_at"] = pd.to_datetime(df4.created_at)
results = df4[(df4.created_at.dt.dayofweek.isin([5,6]))].groupby("login")["created_at"].count().sort_values(ascending=False).head(5).reset_index()
",".join(results["login"].values)
# Out:
# 'LinuxSuRen,zhufengnodejs,xiaoweiruby,i5ting,mozillazg'

# %%
# 15. Do people who are hireable share their email addresses more often?
# [fraction of users with email when hireable=true] minus [fraction of users with email for the rest] 
# (to 3 decimal places, e.g. 0.123 or -0.123)

df_hireable = df_user_profiles[df_user_profiles.hireable == True]
df_non_hireable = df_user_profiles[df_user_profiles.hireable != True]

hireable_fraction = df_hireable[df_hireable.email != ''].shape[0] / df_hireable.shape[0]
non_hireable_fraction = df_non_hireable[df_non_hireable.email != ''].shape[0] / df_non_hireable.shape[0]

np.round(hireable_fraction - non_hireable_fraction, 3)
# Out:
# 0.063

# %%
df_user_profiles.head(2)
# Out:
#          login            name           company        location  \
# 0  michaelliao  Crypto Michael                    Beijing, China
# 1     daimajia             代码家  ZHENFUND BEIJING  Beijing, China
#
#                   email hireable                         bio  public_repos  \
# 0  askxuefeng@gmail.com                    Crypto developer.            99
# 1    daimajia@gmail.com           Zhenfund VP of Investment.            89
#
#    followers  following            created_at
# 0      37254          3  2010-11-06T12:21:35Z
# 1      24631        271  2012-10-07T02:40:06Z

# %%
# 16. Let's assume that the last word in a user's name is their surname 
# (ignore missing names, trim and split by whitespace.) 
# What's the most common surname? (If there's a tie, list them all, comma-separated, alphabetically)
# Number of users with the most common surname

df5 = df_user_profiles[df_user_profiles.name != ''].copy()
df5.name.str.split(" ").str[-1].str.strip().value_counts().head(2)
# Out:
# name
# Zhang    11
# Wang      8
# Name: count, dtype: int64
